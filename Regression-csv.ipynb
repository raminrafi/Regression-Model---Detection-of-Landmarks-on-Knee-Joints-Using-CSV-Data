# %%
import os, glob
import pandas as pd

# %%
PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/csvs"
files = glob.glob(PATH + '/*.csv', recursive=True)

# %% [markdown]
# # Data Preprocessing

# %%
#defining known and unknown landmarks
landmarks = [
    'PCLOrigin',
    'femoralCenter',
    'greaterTrochanter',
    'hipCenter',
    'lateralCondyle',
    'lateralEpicondyle',
    'lateralPosteriorCondyle',
    'medialCondyle',
    'medialEpicondyle',
    'medialPosteriorCondyle',
    'medialSulcus',
    'midfemurCenter',
    'whitesideReference'
]

known_landmarks = [
    'femoralCenter',
    'greaterTrochanter',
    'hipCenter',
    'lateralCondyle',
    'lateralPosteriorCondyle',
    'medialCondyle',
    'medialPosteriorCondyle',
    'midfemurCenter'
]

unknown_landmarks = [
    'PCLOrigin',
    'lateralCondyle',
    'medialCondyle',
    'medialSulcus',
    'whitesideReference'
]

# %%
df = pd.DataFrame()
for file in files:
    df1 = pd.read_csv(file).transpose()
    df1.columns = landmarks
    df = df.append(df1[1:4])

# %%
df.head()
# Out:
#    PCLOrigin femoralCenter greaterTrochanter hipCenter lateralCondyle  \
# x    71.9514       80.6892             127.2   76.6261        102.476
#  y   45.4304       21.1698           22.8131   15.9935        29.3911
#  z   1057.72       1039.01           1438.59   1431.94        1033.13
# x   -80.7702      -93.3621          -132.175  -84.7213       -113.894
#  y   31.8219       13.0114           16.6813    5.3618        20.5354
#
#    lateralEpicondyle lateralPosteriorCondyle medialCondyle medialEpicondyle  \
# x            119.678                 105.667       59.5934          42.2469
#  y           32.7439                 58.7194       36.9582          35.1585
#  z           1057.42                 1053.47       1029.14          1059.21
# x           -127.237                -111.581      -68.2997         -52.6782
#  y           27.7833                 48.3553       18.9857          17.1555
#
#    medialPosteriorCondyle medialSulcus midfemurCenter whitesideReference
# x                 60.4106      44.2516        95.8487            77.3476
#  y                65.4121      44.1233        10.5595            5.62838
#  z                1052.66      1054.91        1240.99            1052.03
# x                -67.8185     -53.9847       -109.553           -95.1252
#  y                46.7843      22.7338         4.6197            -4.0088

# %%
df_x = df[known_landmarks]
df_y = df[unknown_landmarks]

# %%
df_x.head()
# Out:
#    femoralCenter greaterTrochanter hipCenter lateralCondyle  \
# x        80.6892             127.2   76.6261        102.476
#  y       21.1698           22.8131   15.9935        29.3911
#  z       1039.01           1438.59   1431.94        1033.13
# x       -93.3621          -132.175  -84.7213       -113.894
#  y       13.0114           16.6813    5.3618        20.5354
#
#    lateralPosteriorCondyle medialCondyle medialPosteriorCondyle midfemurCenter
# x                  105.667       59.5934                60.4106        95.8487
#  y                 58.7194       36.9582                65.4121        10.5595
#  z                 1053.47       1029.14                1052.66        1240.99
# x                 -111.581      -68.2997               -67.8185       -109.553
#  y                 48.3553       18.9857                46.7843         4.6197

# %%
df_y.head()
# Out:
#    PCLOrigin lateralCondyle medialCondyle medialSulcus whitesideReference
# x    71.9514        102.476       59.5934      44.2516            77.3476
#  y   45.4304        29.3911       36.9582      44.1233            5.62838
#  z   1057.72        1033.13       1029.14      1054.91            1052.03
# x   -80.7702       -113.894      -68.2997     -53.9847           -95.1252
#  y   31.8219        20.5354       18.9857      22.7338            -4.0088

# %%
new_known_landmarks = []
for item in known_landmarks:
    new_known_landmarks.append(item + "_x")
    new_known_landmarks.append(item+"_y")
    new_known_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_x), 3):
    row = [] 
    temp = df_x.iloc(0)
    for item in known_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
    
new_df_x = pd.DataFrame(new_df)
new_df_x.columns = new_known_landmarks

# %%
new_df_x
# Out:
#    femoralCenter_x  femoralCenter_y  femoralCenter_z  greaterTrochanter_x  \
# 0          80.6892          21.1698        1039.0107             127.1995
# 1         -93.3621          13.0114        1116.0123            -132.1748
# 2         -96.9763          -4.3903         978.5149            -126.5539
# 3          42.4078          -9.1362         516.1337             137.7805
# 4         -86.7342           3.1495         346.9031            -146.7723
#
#    greaterTrochanter_y  greaterTrochanter_z  hipCenter_x  hipCenter_y  \
# 0              22.8131            1438.5892      76.6261      15.9935
# 1              16.6813            1526.2719     -84.7213       5.3618
# 2              20.6366            1404.2578     -77.8408       6.3884
# 3               4.0688            1000.5341      72.3962      -4.5555
# 4              11.2634             762.5808     -95.1526     -15.2809
#
#    hipCenter_z  lateralCondyle_x  ...  lateralPosteriorCondyle_z  \
# 0    1431.9423        102.475800  ...                  1053.4742
# 1    1519.0665       -113.893500  ...                  1129.0258
# 2    1400.1727       -120.727100  ...                   994.6252
# 3     996.2128         67.804498  ...                   529.1517
# 4     759.9754       -109.022100  ...                   361.0267
#
#    medialCondyle_x  medialCondyle_y  medialCondyle_z  \
# 0          59.5934          36.9582        1029.1361
# 1         -68.2997          18.9857        1107.5047
# 2         -62.9123           6.7630         968.4417
# 3          13.6013           1.6315         506.1409
# 4         -56.8909          13.6646         339.3879
#
#    medialPosteriorCondyle_x  medialPosteriorCondyle_y  \
# 0                 60.410572                 65.412073
# 1                -67.818500                 46.784300
# 2                -62.007400                 34.593100
# 3                 12.860800                 31.595000
# 4                -56.219300                 41.472500
#
#    medialPosteriorCondyle_z  midfemurCenter_x  midfemurCenter_y  \
# 0               1052.659178           95.8487           10.5595
# 1               1127.728200         -109.5526            4.6197
# 2                991.829800         -103.3541           -5.5297
# 3                530.588800           96.5111          -16.1964
# 4                364.282800         -116.0186          -11.3743
#
#    midfemurCenter_z
# 0         1240.9950
# 1         1324.4932
# 2         1197.4919
# 3          762.3670
# 4          560.6184
#
# [5 rows x 24 columns]

# %%
new_unknown_landmarks = []
for item in unknown_landmarks:
    new_unknown_landmarks.append(item + "_x")
    new_unknown_landmarks.append(item+"_y")
    new_unknown_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_y), 3):
    row = [] 
    temp = df_y.iloc(0)
    for item in unknown_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
    
new_df_y = pd.DataFrame(new_df)
new_df_y.columns = new_unknown_landmarks

# %%
new_df_y["PCLOrigin_x"]
# Out:
# 0    71.9514
# 1   -80.7702
# 2   -79.9650
# 3    32.3282
# 4   -73.2067
# Name: PCLOrigin_x, dtype: float64

# %%
new_df_x
# Out:
#    femoralCenter_x  femoralCenter_y  femoralCenter_z  greaterTrochanter_x  \
# 0          80.6892          21.1698        1039.0107             127.1995
# 1         -93.3621          13.0114        1116.0123            -132.1748
# 2         -96.9763          -4.3903         978.5149            -126.5539
# 3          42.4078          -9.1362         516.1337             137.7805
# 4         -86.7342           3.1495         346.9031            -146.7723
#
#    greaterTrochanter_y  greaterTrochanter_z  hipCenter_x  hipCenter_y  \
# 0              22.8131            1438.5892      76.6261      15.9935
# 1              16.6813            1526.2719     -84.7213       5.3618
# 2              20.6366            1404.2578     -77.8408       6.3884
# 3               4.0688            1000.5341      72.3962      -4.5555
# 4              11.2634             762.5808     -95.1526     -15.2809
#
#    hipCenter_z  lateralCondyle_x  ...  lateralPosteriorCondyle_z  \
# 0    1431.9423        102.475800  ...                  1053.4742
# 1    1519.0665       -113.893500  ...                  1129.0258
# 2    1400.1727       -120.727100  ...                   994.6252
# 3     996.2128         67.804498  ...                   529.1517
# 4     759.9754       -109.022100  ...                   361.0267
#
#    medialCondyle_x  medialCondyle_y  medialCondyle_z  \
# 0          59.5934          36.9582        1029.1361
# 1         -68.2997          18.9857        1107.5047
# 2         -62.9123           6.7630         968.4417
# 3          13.6013           1.6315         506.1409
# 4         -56.8909          13.6646         339.3879
#
#    medialPosteriorCondyle_x  medialPosteriorCondyle_y  \
# 0                 60.410572                 65.412073
# 1                -67.818500                 46.784300
# 2                -62.007400                 34.593100
# 3                 12.860800                 31.595000
# 4                -56.219300                 41.472500
#
#    medialPosteriorCondyle_z  midfemurCenter_x  midfemurCenter_y  \
# 0               1052.659178           95.8487           10.5595
# 1               1127.728200         -109.5526            4.6197
# 2                991.829800         -103.3541           -5.5297
# 3                530.588800           96.5111          -16.1964
# 4                364.282800         -116.0186          -11.3743
#
#    midfemurCenter_z
# 0         1240.9950
# 1         1324.4932
# 2         1197.4919
# 3          762.3670
# 4          560.6184
#
# [5 rows x 24 columns]

# %% [markdown]
# # Model Training

# %%
from sklearn import linear_model

# %%
lm_x = linear_model.LinearRegression()
model_x = lm_x.fit(new_df_x,new_df_y["PCLOrigin_x"])
predictions_x = lm_x.predict(new_df_x)
print("PCLOrigin_x : ", lm_x.score(new_df_x,new_df_y["PCLOrigin_x"]))
# Out:
# PCLOrigin_x :  1.0

# %%
lm_y = linear_model.LinearRegression()
model_y = lm_y.fit(new_df_x,new_df_y["PCLOrigin_y"])
predictions_y = lm_y.predict(new_df_x)
print("PCLOrigin_y : ", lm_y.score(new_df_x,new_df_y["PCLOrigin_y"]))
# Out:
# PCLOrigin_y :  1.0

# %%
lm_z = linear_model.LinearRegression()
model_z = lm_z.fit(new_df_x,new_df_y["PCLOrigin_z"])
predictions_z = lm_z.predict(new_df_x)
print("PCLOrigin_z : ", lm_z.score(new_df_x,new_df_y["PCLOrigin_z"]))
# Out:
# PCLOrigin_z :  1.0

# %%
predictions_x, predictions_y, predictions_z
# Out:
# (array([ 71.9514, -80.7702, -79.965 ,  32.3282, -73.2067]),
#  array([45.4304, 31.8219, 17.6368, 15.4206, 24.9397]),
#  array([1057.7189, 1136.6824,  999.6155,  538.8158,  369.8941]))

# %%
lm_x.predict(new_df_x[4:5])
# Out:
# array([-74.0842294])
