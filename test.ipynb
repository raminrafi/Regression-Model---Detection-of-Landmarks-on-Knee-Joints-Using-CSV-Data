# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('csgo.png')
texted_image =cv2.putText(img=np.copy(image), text="hello", org=(200,200),fontFace=3, fontScale=3, color=(0,0,255), thickness=5)
plt.imshow(texted_image)
plt.show()
