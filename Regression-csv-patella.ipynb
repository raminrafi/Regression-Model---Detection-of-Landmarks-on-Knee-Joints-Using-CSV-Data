# %%
import os, glob
import pandas as pd

# %% [markdown]
# # Transform data only run once

# %%
# PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/Dataset/Right"
# NEW_PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/csvs-patella/"
# files = glob.glob(PATH + '/*/Landmarks_patella.csv', recursive=True)
# text = "landmark,x, y, z\n"
# for file in files:
#     with open(file) as f:
#         data = f.read()
#     new_data = text + data
#     splited = file.rsplit('/', 2)
#     path_to_store = NEW_PATH + "{} {}".format(splited[1], splited[2])
#     with open(path_to_store, "w+") as fn:
#         fn.write(new_data)

# %% [markdown]
# # Remove femCMPImportREF

# %% [markdown]
# ## Only run once

# %%
# PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/csvs-patella/"
# files = glob.glob(PATH + '/*.csv', recursive=True)
# for file in files:
#     with open(file) as f:
#         data = f.readlines()
#     if "patCMPImportREF" in data[-1]:
#         new_data = data[:len(data)-1]
#     else:
#         new_data = data
#     new_data = "".join(new_data)
#     splited = file.rsplit('/', 2)
#     path_to_store = file
#     with open(path_to_store, "w+") as fn:
#         fn.write(new_data)

# %% [markdown]
# # Data Preprocessing

# %%
PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/csvs-patella/"
files = glob.glob(PATH + '/*.csv', recursive=True)

# %%
#defining known and unknown landmarks
landmarks = [
    "anteriorApex",
    "quadTendonInsertion",
    "patTendonOrigin",
    "MedialEdge",
    "LateralEdge",
    "posteriorApex"
]

known_landmarks = [
    "anteriorApex",
    "quadTendonInsertion",
    "patTendonOrigin",
    "MedialEdge",
    "LateralEdge"
]

unknown_landmarks = [
    "posteriorApex"
]

# %%
# Loading train dataset
df = pd.DataFrame()
for file in files:
    df1 = pd.read_csv(file).transpose()
    temp = []
    for item in df1.iloc[0]:
        temp.append(item)
    df1.columns = temp
    df = df.append(df1[1:4])

# %%
df.head()
# Out:
#    LateralEdge MedialEdge anteriorApex patTendonOrigin posteriorApex  \
# x      -109.04   -68.0331     -85.6022        -86.1895      -86.0687
#  y    -31.3015   -23.4092     -36.6497        -27.1984      -18.9003
#  z     1372.52    1372.98      1365.83         1350.44       1370.96
# x      -125.17   -70.8802      -94.065        -100.497      -92.4381
#  y     -88.198   -89.5517     -100.574        -89.3941      -79.1623
#
#    quadTendonInsertion
# x             -87.3317
#  y            -32.0526
#  z              1385.4
# x             -93.9647
#  y            -95.5736

# %%
# spliting trin dataset
df_x = df[known_landmarks]
df_y = df[unknown_landmarks]

# %%
df_x.head()
# Out:
#    anteriorApex quadTendonInsertion patTendonOrigin MedialEdge LateralEdge
# x      -85.6022            -87.3317        -86.1895   -68.0331     -109.04
#  y     -36.6497            -32.0526        -27.1984   -23.4092    -31.3015
#  z      1365.83              1385.4         1350.44    1372.98     1372.52
# x       -94.065            -93.9647        -100.497   -70.8802     -125.17
#  y     -100.574            -95.5736        -89.3941   -89.5517     -88.198

# %%
df_y.head()
# Out:
#    posteriorApex
# x       -86.0687
#  y      -18.9003
#  z       1370.96
# x       -92.4381
#  y      -79.1623

# %%
# Transforming dataframe so that each patient is represented as 1 example to model

new_known_landmarks = []
for item in df_x.columns:
    new_known_landmarks.append(item + "_x")
    new_known_landmarks.append(item+"_y")
    new_known_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_x), 3):
    row = [] 
    temp = df_x.iloc(0)
    for item in known_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
new_df_x = pd.DataFrame(new_df)
new_df_x.columns = new_known_landmarks

# %%
new_df_x.head()
# Out:
#    anteriorApex_x  anteriorApex_y  anteriorApex_z  quadTendonInsertion_x  \
# 0       -85.60220       -36.64970       1365.8301               -87.3317
# 1       -94.06500      -100.57405        432.2751               -93.9647
# 2       -77.37000       -54.03000        380.8500               -77.9800
# 3       -71.90000       -84.85000        444.8400               -70.7600
# 4      -114.04025       -68.16985        449.5452              -110.1138
#
#    quadTendonInsertion_y  quadTendonInsertion_z  patTendonOrigin_x  \
# 0               -32.0526              1385.4024          -86.18950
# 1               -95.5736               454.8592         -100.49655
# 2               -48.7200               401.9500          -80.23000
# 3               -78.3200               468.2700          -72.94000
# 4               -64.4056               469.0220         -110.76915
#
#    patTendonOrigin_y  patTendonOrigin_z  MedialEdge_x  MedialEdge_y  \
# 0          -27.19840         1350.44300      -68.0331     -23.40920
# 1          -89.39410          414.15725      -70.8802     -89.55170
# 2          -44.51000          363.49000      -58.1800     -44.57000
# 3          -76.49000          426.01000      -46.5700     -66.83000
# 4          -58.22195          430.68355      -90.4601     -67.99055
#
#    MedialEdge_z  LateralEdge_x  LateralEdge_y  LateralEdge_z
# 0     1372.9776     -109.03990      -31.30150     1372.51990
# 1      438.1628     -125.16990      -88.19805      443.01155
# 2      388.2200     -102.48000      -43.47000      390.95000
# 3      448.4400      -97.67000      -73.14000      454.41000
# 4      452.2217     -130.07905      -53.76405      457.91805

# %%
# Transforming dataframe so that each patient is represented as 1 example to model

new_unknown_landmarks = []
for item in unknown_landmarks:
    new_unknown_landmarks.append(item + "_x")
    new_unknown_landmarks.append(item+"_y")
    new_unknown_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_y), 3):
    row = [] 
    temp = df_y.iloc(0)
    for item in unknown_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
    
new_df_y = pd.DataFrame(new_df)
new_df_y.columns = new_unknown_landmarks

# %%
new_df_y["posteriorApex_x"].head()
# Out:
# 0    -86.06870
# 1    -92.43815
# 2    -77.30000
# 3    -69.52000
# 4   -101.71430
# Name: posteriorApex_x, dtype: float64

# %%
new_df_x.head()
# Out:
#    anteriorApex_x  anteriorApex_y  anteriorApex_z  quadTendonInsertion_x  \
# 0       -85.60220       -36.64970       1365.8301               -87.3317
# 1       -94.06500      -100.57405        432.2751               -93.9647
# 2       -77.37000       -54.03000        380.8500               -77.9800
# 3       -71.90000       -84.85000        444.8400               -70.7600
# 4      -114.04025       -68.16985        449.5452              -110.1138
#
#    quadTendonInsertion_y  quadTendonInsertion_z  patTendonOrigin_x  \
# 0               -32.0526              1385.4024          -86.18950
# 1               -95.5736               454.8592         -100.49655
# 2               -48.7200               401.9500          -80.23000
# 3               -78.3200               468.2700          -72.94000
# 4               -64.4056               469.0220         -110.76915
#
#    patTendonOrigin_y  patTendonOrigin_z  MedialEdge_x  MedialEdge_y  \
# 0          -27.19840         1350.44300      -68.0331     -23.40920
# 1          -89.39410          414.15725      -70.8802     -89.55170
# 2          -44.51000          363.49000      -58.1800     -44.57000
# 3          -76.49000          426.01000      -46.5700     -66.83000
# 4          -58.22195          430.68355      -90.4601     -67.99055
#
#    MedialEdge_z  LateralEdge_x  LateralEdge_y  LateralEdge_z
# 0     1372.9776     -109.03990      -31.30150     1372.51990
# 1      438.1628     -125.16990      -88.19805      443.01155
# 2      388.2200     -102.48000      -43.47000      390.95000
# 3      448.4400      -97.67000      -73.14000      454.41000
# 4      452.2217     -130.07905      -53.76405      457.91805

# %% [markdown]
# # Model Training

# %%
from sklearn import linear_model

# %% [markdown]
# ## posteriorApex training

# %%
lm_x_po = linear_model.LinearRegression()
model_x = lm_x_po.fit(new_df_x,new_df_y["posteriorApex_x"])
lm_y_po = linear_model.LinearRegression()
model_y = lm_y_po.fit(new_df_x,new_df_y["posteriorApex_y"])
lm_z_po = linear_model.LinearRegression()
model_z = lm_z_po.fit(new_df_x,new_df_y["posteriorApex_z"])

# %% [markdown]
# # Prediction testing

# %%
PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/csvs-test-petella/"
files = glob.glob(PATH + '/*.csv', recursive=True)

# %%
# Loading test dataset
df = pd.DataFrame()
for file in files:
    df1 = pd.read_csv(file).transpose()
    temp = []
    for item in df1.iloc[0]:
        temp.append(item)
    df1.columns = temp
    df = df.append(df1[1:4])

# %%
# spliting test dataset
df_x = df[known_landmarks]
df_y = df[unknown_landmarks]

# %%
# transforming test dataset for prediction
new_known_landmarks = []
for item in df_x.columns:
    new_known_landmarks.append(item + "_x")
    new_known_landmarks.append(item+"_y")
    new_known_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_x), 3):
    row = [] 
    temp = df_x.iloc(0)
    for item in known_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
new_df_x = pd.DataFrame(new_df)
new_df_x.columns = new_known_landmarks

# %%
# transforming test dataset for prediction

new_unknown_landmarks = []
for item in unknown_landmarks:
    new_unknown_landmarks.append(item + "_x")
    new_unknown_landmarks.append(item+"_y")
    new_unknown_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_y), 3):
    row = [] 
    temp = df_y.iloc(0)
    for item in unknown_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
    
new_df_y = pd.DataFrame(new_df)
new_df_y.columns = new_unknown_landmarks

# %% [markdown]
# ## posteriorApex_test

# %%
#pedict PCL_origin 
predictions_x = lm_x_po.predict(new_df_x)
predictions_y = lm_y_po.predict(new_df_x)
predictions_z = lm_z_po.predict(new_df_x)
posteriorApex_predictions = []
for i, x in enumerate(predictions_z):
    posteriorApex_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
posteriorApex_df = pd.DataFrame(posteriorApex_predictions)
posteriorApex_df.columns= ["posteriorApex_x", "posteriorApex_y", "posteriorApex_z"]
print("\nPredicted Values!!!")
posteriorApex_df
# Out:
# Predicted Values!!!
#    posteriorApex_x  posteriorApex_y  posteriorApex_z
# 0      -117.056385       -53.527236       453.839330
# 1      -136.394740       -74.507183       452.058478
# 2       -76.258357       -34.003510       447.688188

# %%
print("\nActual Values!!!")
new_df_y[["posteriorApex_x", "posteriorApex_y", "posteriorApex_z"]]
# Out:
# Actual Values!!!
#    posteriorApex_x  posteriorApex_y  posteriorApex_z
# 0        -117.2500          -54.940          452.530
# 1        -138.3247          -70.305          454.733
# 2         -77.7200          -33.280          449.940
