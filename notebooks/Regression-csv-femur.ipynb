# %%
import os, glob
import pandas as pd

# %% [markdown]
# # Transform data only run once

# %%
# PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/Dataset/Landmarks"
# NEW_PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/Dataset/csvs/"
# files = glob.glob(PATH + '/Femur/*.csv', recursive=True)
# text = "landmark,x, y, z\n"
# for file in files:
#     with open(file) as f:
#         data = f.read()
#     new_data = text + data
#     splited = file.rsplit('/', 2)
#     path_to_store = NEW_PATH + "{} {}".format(splited[1], splited[2])
#     with open(path_to_store, "w+") as fn:
#         fn.write(new_data)

# %% [markdown]
# # Remove femCMPImportREF

# %% [markdown]
# ## Only run once

# %%
# PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/Dataset/csvs/"
# files = glob.glob(PATH + '/*.csv', recursive=True)
# for file in files:
#     with open(file) as f:
#         data = f.readlines()
#     if "femCMPImportREF" in data[-1]:
#         new_data = data[:len(data)-1]
#     else:
#         new_data = data
#     new_data = "".join(new_data)
#     splited = file.rsplit('/', 2)
#     path_to_store = file
#     with open(path_to_store, "w+") as fn:
#         fn.write(new_data)

# %% [markdown]
# # Data Preprocessing

# %%
PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/Dataset/csvs/"
files = glob.glob(PATH + '/*.csv', recursive=True)

# %%
#defining known and unknown landmarks
landmarks = [
    'PCLOrigin',
    'femoralCenter',
    'greaterTrochanter',
    'hipCenter',
    'lateralCondyle',
    'lateralEpicondyle',
    'lateralPosteriorCondyle',
    'medialCondyle',
    'medialEpicondyle',
    'medialPosteriorCondyle',
    'medialSulcus',
    'midfemurCenter',
    'whitesideReference'
]
#    'femoralCenter',
known_landmarks = [
    'greaterTrochanter',
    'hipCenter',
    'lateralEpicondyle',
    'lateralPosteriorCondyle',
    'medialEpicondyle',
    'medialPosteriorCondyle',
    'midfemurCenter'
]

unknown_landmarks = [
    'PCLOrigin',
    'lateralCondyle',
    'medialCondyle',
    'medialSulcus',
    'femoralCenter',
    'whitesideReference'
]

# %%
# Loading train dataset
df = pd.DataFrame()
for file in files:
    df1 = pd.read_csv(file).transpose()
    temp = []
    for item in df1.iloc[0]:
        temp.append(item)
    df1.columns = temp
    df = df.append(df1[1:4])

# %%
df.head()
# Out:
#    PCLOrigin femoralCenter greaterTrochanter hipCenter lateralCondyle  \
# x     -64.01         -73.9           -138.02    -85.67        -101.32
#  y     26.89           1.9             22.78       6.7           13.8
#  z    498.21        475.64            984.23    983.37         468.11
# x     120.63        134.17            147.21    100.45          154.5
#  y     -0.79        -22.04                17     -4.38         -13.86
#
#    lateralEpicondyle lateralPosteriorCondyle medialCondyle medialEpicondyle  \
# x            -116.63                 -100.89        -48.14           -31.03
#  y             12.84                   41.54         14.06            15.25
#  z            496.29                  490.52        465.61           496.03
# x             170.56                  152.07        107.65            89.09
#  y             -4.26                   17.91        -17.06              -20
#
#    medialPosteriorCondyle medialSulcus midfemurCenter whitesideReference
# x                  -49.27        -33.2         -98.24             -68.86
#  y                  47.38        23.46           -1.3             -17.45
#  z                 489.43       493.23         736.86             491.42
# x                  107.31        90.65         140.35             135.83
#  y                  15.19       -12.16         -17.56             -45.36

# %%
# spliting trin dataset
df_x = df[known_landmarks]
df_y = df[unknown_landmarks]

# %%
df_x.head()
# Out:
#    greaterTrochanter hipCenter lateralEpicondyle lateralPosteriorCondyle  \
# x            -138.02    -85.67           -116.63                 -100.89
#  y             22.78       6.7             12.84                   41.54
#  z            984.23    983.37            496.29                  490.52
# x             147.21    100.45            170.56                  152.07
#  y                17     -4.38             -4.26                   17.91
#
#    medialEpicondyle medialPosteriorCondyle midfemurCenter
# x            -31.03                 -49.27         -98.24
#  y            15.25                  47.38           -1.3
#  z           496.03                 489.43         736.86
# x             89.09                 107.31         140.35
#  y              -20                  15.19         -17.56

# %%
df_y.head()
# Out:
#    PCLOrigin lateralCondyle medialCondyle medialSulcus femoralCenter  \
# x     -64.01        -101.32        -48.14        -33.2         -73.9
#  y     26.89           13.8         14.06        23.46           1.9
#  z    498.21         468.11        465.61       493.23        475.64
# x     120.63          154.5        107.65        90.65        134.17
#  y     -0.79         -13.86        -17.06       -12.16        -22.04
#
#    whitesideReference
# x              -68.86
#  y             -17.45
#  z             491.42
# x              135.83
#  y             -45.36

# %%
# Transforming dataframe so that each patient is represented as 1 example to model

new_known_landmarks = []
for item in df_x.columns:
    new_known_landmarks.append(item + "_x")
    new_known_landmarks.append(item+"_y")
    new_known_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_x), 3):
    row = [] 
    temp = df_x.iloc(0)
    for item in known_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
new_df_x = pd.DataFrame(new_df)
new_df_x.columns = new_known_landmarks

# %%
new_df_x.head()
# Out:
#    greaterTrochanter_x  greaterTrochanter_y  greaterTrochanter_z  hipCenter_x  \
# 0              -138.02                22.78               984.23       -85.67
# 1               147.21                17.00              1486.54       100.45
# 2               155.50                -4.67               -78.89        98.97
# 3               141.28              -115.56              -111.59        92.80
# 4               143.21                -7.64              1301.63        89.04
#
#    hipCenter_y  hipCenter_z  lateralEpicondyle_x  lateralEpicondyle_y  \
# 0         6.70       983.37              -116.63                12.84
# 1        -4.38      1473.25               170.56                -4.26
# 2       -19.66       -77.10               117.15               -31.63
# 3      -126.56      -111.77               102.46               -98.17
# 4       -15.00      1289.36               165.37                -6.61
#
#    lateralEpicondyle_z  lateralPosteriorCondyle_x  ...  \
# 0               496.29                    -100.89  ...
# 1              1072.43                     152.07  ...
# 2              -530.33                      93.37  ...
# 3              -519.26                      87.68  ...
# 4               878.63                     147.48  ...
#
#    lateralPosteriorCondyle_z  medialEpicondyle_x  medialEpicondyle_y  \
# 0                     490.52              -31.03               15.25
# 1                    1069.99               89.09              -20.00
# 2                    -535.42               25.81              -44.83
# 3                    -523.79               20.86              -95.23
# 4                     871.62               79.55              -16.27
#
#    medialEpicondyle_z  medialPosteriorCondyle_x  medialPosteriorCondyle_y  \
# 0              496.03                    -49.27                     47.38
# 1             1074.01                    107.31                     15.19
# 2             -527.65                     47.33                     -6.16
# 3             -520.61                     41.68                    -67.32
# 4              869.35                     95.72                     16.73
#
#    medialPosteriorCondyle_z  midfemurCenter_x  midfemurCenter_y  \
# 0                    489.43            -98.24             -1.30
# 1                   1070.64            140.35            -17.56
# 2                   -531.52             86.20            -54.74
# 3                   -524.07             93.89           -119.77
# 4                    865.51            130.59            -27.98
#
#    midfemurCenter_z
# 0            736.86
# 1           1270.99
# 2           -451.38
# 3           -320.51
# 4           1078.46
#
# [5 rows x 21 columns]

# %%
# Transforming dataframe so that each patient is represented as 1 example to model

new_unknown_landmarks = []
for item in unknown_landmarks:
    new_unknown_landmarks.append(item + "_x")
    new_unknown_landmarks.append(item+"_y")
    new_unknown_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_y), 3):
    row = [] 
    temp = df_y.iloc(0)
    for item in unknown_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
    
new_df_y = pd.DataFrame(new_df)
new_df_y.columns = new_unknown_landmarks

# %%
new_df_y["PCLOrigin_x"].head()
# Out:
# 0    -64.01
# 1    120.63
# 2     61.83
# 3     52.94
# 4    112.11
# Name: PCLOrigin_x, dtype: float64

# %%
new_df_x.head()
# Out:
#    greaterTrochanter_x  greaterTrochanter_y  greaterTrochanter_z  hipCenter_x  \
# 0              -138.02                22.78               984.23       -85.67
# 1               147.21                17.00              1486.54       100.45
# 2               155.50                -4.67               -78.89        98.97
# 3               141.28              -115.56              -111.59        92.80
# 4               143.21                -7.64              1301.63        89.04
#
#    hipCenter_y  hipCenter_z  lateralEpicondyle_x  lateralEpicondyle_y  \
# 0         6.70       983.37              -116.63                12.84
# 1        -4.38      1473.25               170.56                -4.26
# 2       -19.66       -77.10               117.15               -31.63
# 3      -126.56      -111.77               102.46               -98.17
# 4       -15.00      1289.36               165.37                -6.61
#
#    lateralEpicondyle_z  lateralPosteriorCondyle_x  ...  \
# 0               496.29                    -100.89  ...
# 1              1072.43                     152.07  ...
# 2              -530.33                      93.37  ...
# 3              -519.26                      87.68  ...
# 4               878.63                     147.48  ...
#
#    lateralPosteriorCondyle_z  medialEpicondyle_x  medialEpicondyle_y  \
# 0                     490.52              -31.03               15.25
# 1                    1069.99               89.09              -20.00
# 2                    -535.42               25.81              -44.83
# 3                    -523.79               20.86              -95.23
# 4                     871.62               79.55              -16.27
#
#    medialEpicondyle_z  medialPosteriorCondyle_x  medialPosteriorCondyle_y  \
# 0              496.03                    -49.27                     47.38
# 1             1074.01                    107.31                     15.19
# 2             -527.65                     47.33                     -6.16
# 3             -520.61                     41.68                    -67.32
# 4              869.35                     95.72                     16.73
#
#    medialPosteriorCondyle_z  midfemurCenter_x  midfemurCenter_y  \
# 0                    489.43            -98.24             -1.30
# 1                   1070.64            140.35            -17.56
# 2                   -531.52             86.20            -54.74
# 3                   -524.07             93.89           -119.77
# 4                    865.51            130.59            -27.98
#
#    midfemurCenter_z
# 0            736.86
# 1           1270.99
# 2           -451.38
# 3           -320.51
# 4           1078.46
#
# [5 rows x 21 columns]

# %%
def nans(df): return df[df.isnull().any(axis=1)]
nans(new_df_x)
# Out:
# Empty DataFrame
# Columns: [greaterTrochanter_x, greaterTrochanter_y, greaterTrochanter_z, hipCenter_x, hipCenter_y, hipCenter_z, lateralEpicondyle_x, lateralEpicondyle_y, lateralEpicondyle_z, lateralPosteriorCondyle_x, lateralPosteriorCondyle_y, lateralPosteriorCondyle_z, medialEpicondyle_x, medialEpicondyle_y, medialEpicondyle_z, medialPosteriorCondyle_x, medialPosteriorCondyle_y, medialPosteriorCondyle_z, midfemurCenter_x, midfemurCenter_y, midfemurCenter_z]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# # Model Training

# %%
from sklearn import linear_model
import statsmodels.api as sm

# %% [markdown]
# ## PCLOrigin training

# %%
lm_x_po = linear_model.LinearRegression()
model_x = lm_x_po.fit(new_df_x,new_df_y["PCLOrigin_x"])
lm_y_po = linear_model.LinearRegression()
model_y = lm_y_po.fit(new_df_x,new_df_y["PCLOrigin_y"])
lm_z_po = linear_model.LinearRegression()
model_z = lm_z_po.fit(new_df_x,new_df_y["PCLOrigin_z"])

# %% [markdown]
# ## lateralCondyle training

# %%
lm_x_lc = linear_model.LinearRegression()
model_x = lm_x_lc.fit(new_df_x,new_df_y["lateralCondyle_x"])
lm_y_lc = linear_model.LinearRegression()
model_y = lm_y_lc.fit(new_df_x,new_df_y["lateralCondyle_y"])
lm_z_lc = linear_model.LinearRegression()
model_z = lm_z_lc.fit(new_df_x,new_df_y["lateralCondyle_z"])

# %% [markdown]
# ## medialCondyle training

# %%
lm_x_mc = linear_model.LinearRegression()
model_x = lm_x_mc.fit(new_df_x,new_df_y["medialCondyle_x"])
lm_y_mc = linear_model.LinearRegression()
model_y = lm_y_mc.fit(new_df_x,new_df_y["medialCondyle_y"])
lm_z_mc = linear_model.LinearRegression()
model_z = lm_z_mc.fit(new_df_x,new_df_y["medialCondyle_z"])

# %% [markdown]
# ## medialSulcus training

# %%
lm_x_ms = linear_model.LinearRegression()
model_x = lm_x_ms.fit(new_df_x,new_df_y["medialSulcus_x"])
lm_y_ms = linear_model.LinearRegression()
model_y = lm_y_ms.fit(new_df_x,new_df_y["medialSulcus_y"])
lm_z_ms = linear_model.LinearRegression()
model_z = lm_z_ms.fit(new_df_x,new_df_y["medialSulcus_z"])

# %% [markdown]
# ## whitesideReference training

# %%
lm_x_wr = linear_model.LinearRegression()
model_x = lm_x_wr.fit(new_df_x,new_df_y["whitesideReference_x"])
lm_y_wr = linear_model.LinearRegression()
model_y = lm_y_wr.fit(new_df_x,new_df_y["whitesideReference_y"])
lm_z_wr = linear_model.LinearRegression()
model_z = lm_z_wr.fit(new_df_x,new_df_y["whitesideReference_z"])

# %% [markdown]
# ## femoralCenter training

# %%
lm_x_fc = linear_model.LinearRegression()
model_x = lm_x_fc.fit(new_df_x,new_df_y["femoralCenter_x"])
lm_y_fc = linear_model.LinearRegression()
model_y = lm_y_fc.fit(new_df_x,new_df_y["femoralCenter_y"])
lm_z_fc = linear_model.LinearRegression()
model_z = lm_z_fc.fit(new_df_x,new_df_y["femoralCenter_z"])

# %%
model1 = sm.OLS(new_df_y["femoralCenter_x"],new_df_x).fit()
model2 = sm.OLS(new_df_y["femoralCenter_y"],new_df_x).fit()
model3 = sm.OLS(new_df_y["femoralCenter_z"],new_df_x).fit()

# %% [markdown]
# # Prediction testing

# %%
PATH = "/Users/apple/Desktop/Development/freelance/upwork/brad-miles/Landmarks-Detection/Dataset/csvs-test/"
files = glob.glob(PATH + '/*.csv', recursive=True)

# %%
# Loading test dataset
df = pd.DataFrame()
for file in files:
    df1 = pd.read_csv(file).transpose()
    temp = []
    for item in df1.iloc[0]:
        temp.append(item)
    df1.columns = temp
    df = df.append(df1[1:4])

# %%
# spliting test dataset
df_x = df[known_landmarks]
df_y = df[unknown_landmarks]

# %%
# transforming test dataset for prediction
new_known_landmarks = []
for item in df_x.columns:
    new_known_landmarks.append(item + "_x")
    new_known_landmarks.append(item+"_y")
    new_known_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_x), 3):
    row = [] 
    temp = df_x.iloc(0)
    for item in known_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
new_df_x = pd.DataFrame(new_df)
new_df_x.columns = new_known_landmarks

# %%
# transforming test dataset for prediction

new_unknown_landmarks = []
for item in unknown_landmarks:
    new_unknown_landmarks.append(item + "_x")
    new_unknown_landmarks.append(item+"_y")
    new_unknown_landmarks.append(item+"_z")
    
new_df = []
for i in range(0, len(df_y), 3):
    row = [] 
    temp = df_y.iloc(0)
    for item in unknown_landmarks:
        row.append(temp[i][item])
        row.append(temp[i+1][item])
        row.append(temp[i+2][item])
    new_df.append(row)
    
new_df_y = pd.DataFrame(new_df)
new_df_y.columns = new_unknown_landmarks

# %% [markdown]
# ## PCL_orgin_test

# %%
#pedict PCL_origin 
predictions_x = lm_x_po.predict(new_df_x)
predictions_y = lm_y_po.predict(new_df_x)
predictions_z = lm_z_po.predict(new_df_x)
PCL_origin_predictions = []
for i, x in enumerate(predictions_z):
    PCL_origin_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
PCL_origin_df = pd.DataFrame(PCL_origin_predictions)
PCL_origin_df.columns= ["PCLOrigin_x", "PCLOrigin_y", "PCLOrigin_z"]
print("\nPredicted Values!!!")
PCL_origin_df
# Out:
# Predicted Values!!!
#    PCLOrigin_x  PCLOrigin_y  PCLOrigin_z
# 0   -76.025012   196.572946  -585.806961
# 1  -104.668108    29.301769  1289.404650
# 2    69.806745   -19.020267   495.172744
# 3   -79.772122    59.988493  -548.342390
# 4   -94.584642   -83.452609  1082.724580

# %%
print("\nActual Values!!!")
new_df_y[["PCLOrigin_x", "PCLOrigin_y", "PCLOrigin_z"]]
# Out:
# Actual Values!!!
#    PCLOrigin_x  PCLOrigin_y  PCLOrigin_z
# 0       -75.14       197.36      -585.45
# 1      -101.97        30.50      1290.31
# 2        70.95       -17.85       497.53
# 3       -79.45        62.04      -547.40
# 4       -91.59       -83.50      1083.23

# %% [markdown]
# ## lateralCondyle_test

# %%
#pedict lateralCondyle 
predictions_x = lm_x_lc.predict(new_df_x)
predictions_y = lm_y_lc.predict(new_df_x)
predictions_z = lm_z_lc.predict(new_df_x)
lateralCondyle_predictions = []
for i, x in enumerate(predictions_z):
    lateralCondyle_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
lateralCondyle_df = pd.DataFrame(lateralCondyle_predictions)
lateralCondyle_df.columns= ["lateralCondyle_x", "lateralCondyle_y", "lateralCondyle_z"]
print("\nPredicted Values!!!")
lateralCondyle_df
# Out:
# Predicted Values!!!
#    lateralCondyle_x  lateralCondyle_y  lateralCondyle_z
# 0       -109.543782        181.940733       -613.543408
# 1       -137.513216         12.805666       1261.731577
# 2        103.898493        -26.245734        465.927276
# 3       -113.934223         58.599080       -576.557642
# 4       -122.141904       -102.914872       1054.955593

# %%
print("\nActual Values!!!")
new_df_y[["lateralCondyle_x", "lateralCondyle_y", "lateralCondyle_z"]]
# Out:
# Actual Values!!!
#    lateralCondyle_x  lateralCondyle_y  lateralCondyle_z
# 0           -106.40            182.61           -611.33
# 1           -134.20             13.70           1260.50
# 2            108.26            -23.42            467.10
# 3           -117.12             56.52           -578.37
# 4           -120.10           -103.12           1055.30

# %% [markdown]
# ## medialCondyle_test

# %%
#predict medialCondyle
predictions_x = lm_x_mc.predict(new_df_x)
predictions_y = lm_y_mc.predict(new_df_x)
predictions_z = lm_z_mc.predict(new_df_x)
medialCondyle_predictions = []
for i, x in enumerate(predictions_z):
    medialCondyle_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
medialCondyle_df = pd.DataFrame(medialCondyle_predictions)
medialCondyle_df.columns= ["medialCondyle_x", "medialCondyle_y", "medialCondyle_z"]
print("\nPredicted Values!!!")
medialCondyle_df
# Out:
# Predicted Values!!!
#    medialCondyle_x  medialCondyle_y  medialCondyle_z
# 0       -60.949210       186.185416      -615.719265
# 1       -90.069266        21.134530      1258.792698
# 2        55.661922       -33.117265       464.159219
# 3       -69.483502        43.330153      -583.205502
# 4       -78.720390       -89.944957      1052.696893

# %%
print("\nActual Values!!!")
new_df_y[["medialCondyle_x", "medialCondyle_y", "medialCondyle_z"]]
# Out:
# Actual Values!!!
#    medialCondyle_x  medialCondyle_y  medialCondyle_z
# 0           -57.85           185.83          -614.42
# 1           -86.45            20.24          1257.50
# 2            53.21           -34.21           464.92
# 3           -70.66            45.15          -584.51
# 4           -75.62           -89.93          1051.38

# %% [markdown]
# ## medialSulcus_test

# %%
#predict medialSulcus

predictions_x = lm_x_ms.predict(new_df_x)
predictions_y = lm_y_ms.predict(new_df_x)
predictions_z = lm_z_ms.predict(new_df_x)
medialSulcus_predictions = []
for i, x in enumerate(predictions_z):
    medialSulcus_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
medialSulcus_df = pd.DataFrame(medialSulcus_predictions)
medialSulcus_df.columns= ["medialSulcus_x", "medialSulcus_y", "medialSulcus_z"]
print("\nPredicted Values!!!")
medialSulcus_df
# Out:
# Predicted Values!!!
#    medialSulcus_x  medialSulcus_y  medialSulcus_z
# 0      -41.700532      192.825881     -589.455984
# 1      -71.717326       28.067634     1282.748192
# 2       41.073496      -30.746099      489.787377
# 3      -56.865586       39.665395     -555.800408
# 4      -63.400595      -81.824345     1077.596729

# %%
print("\nActual Values!!!")
new_df_y[["medialSulcus_x", "medialSulcus_y", "medialSulcus_z"]]
# Out:
# Actual Values!!!
#    medialSulcus_x  medialSulcus_y  medialSulcus_z
# 0          -44.80          192.01         -589.09
# 1          -74.17           27.67         1283.22
# 2           39.09          -31.13          490.15
# 3          -52.77           39.33         -554.73
# 4          -64.10          -83.18         1077.74

# %% [markdown]
# ## whitesideReference_test

# %%
#predict whitesideReference
predictions_x = lm_x_wr.predict(new_df_x)
predictions_y = lm_y_wr.predict(new_df_x)
predictions_z = lm_z_wr.predict(new_df_x)
whitesideReference_predictions = []
for i, x in enumerate(predictions_z):
    whitesideReference_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
whitesideReference_df = pd.DataFrame(whitesideReference_predictions)
whitesideReference_df.columns= ["whitesideReference_x", "whitesideReference_y", "whitesideReference_z"]
print("\nPredicted Values!!!")
whitesideReference_df
# Out:
# Predicted Values!!!
#    whitesideReference_x  whitesideReference_y  whitesideReference_z
# 0            -86.140930            155.988577           -592.225344
# 1           -114.886341            -10.319509           1276.689863
# 2             84.186572            -57.738181            485.891394
# 3           -103.512243             21.471790           -558.832283
# 4            -96.889822           -123.080197           1071.156247

# %%
print("\nActual Values!!!")
new_df_y[["whitesideReference_x", "whitesideReference_y", "whitesideReference_z"]]
# Out:
# Actual Values!!!
#    whitesideReference_x  whitesideReference_y  whitesideReference_z
# 0                -83.31                156.74               -592.80
# 1               -110.81                 -9.86               1280.81
# 2                 86.14                -51.62                484.81
# 3               -105.88                 23.68               -556.91
# 4                -92.70               -125.77               1072.24

# %% [markdown]
# ## femoralCenter_test

# %%
#predict whitesideReference
predictions_x = lm_x_fc.predict(new_df_x)
predictions_y = lm_y_fc.predict(new_df_x)
predictions_z = lm_z_fc.predict(new_df_x)
femoralCenter_predictions = []
for i, x in enumerate(predictions_z):
    femoralCenter_predictions.append([predictions_x[i], predictions_y[i], x])

# %%
femoralCenter_df = pd.DataFrame(femoralCenter_predictions)
femoralCenter_df.columns= ["femoralCenter_x", "femoralCenter_y", "femoralCenter_z"]
print("\nPredicted Values!!!")
femoralCenter_df
# Out:
# Predicted Values!!!
#    femoralCenter_x  femoralCenter_y  femoralCenter_z
# 0       -86.269406       175.000319      -604.641149
# 1      -115.988112         8.869025      1262.843809
# 2        81.863955       -37.505339       471.133814
# 3       -96.274933        41.965886      -573.025762
# 4       -99.949547      -104.565515      1059.483676

# %%
print("\nActual Values!!!")
new_df_y[["femoralCenter_x", "femoralCenter_y", "femoralCenter_z"]]
# Out:
# Actual Values!!!
#    femoralCenter_x  femoralCenter_y  femoralCenter_z
# 0           -85.11           178.88          -606.50
# 1          -112.31             9.37          1266.51
# 2            85.01           -38.92           474.68
# 3           -98.37            45.57          -573.35
# 4           -97.46          -106.34          1061.26

# %%
predictions1 = model1.predict(new_df_x)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        femoralCenter_x   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          1.174e+05
# Date:                Thu, 27 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        20:03:25   Log-Likelihood:                         -4980.5
# No. Observations:                2039   AIC:                                  1.000e+04
# Df Residuals:                    2018   BIC:                                  1.012e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# greaterTrochanter_x           0.0390      0.014      2.876      0.004       0.012       0.066
# greaterTrochanter_y          -0.0045      0.010     -0.472      0.637      -0.023       0.014
# greaterTrochanter_z           0.0335      0.007      4.954      0.000       0.020       0.047
# hipCenter_x                  -0.1480      0.014    -10.308      0.000      -0.176      -0.120
# hipCenter_y                   0.0049      0.010      0.510      0.610      -0.014       0.024
# hipCenter_z                  -0.0378      0.007     -5.783      0.000      -0.051      -0.025
# lateralEpicondyle_x           0.0659      0.006     11.870      0.000       0.055       0.077
# lateralEpicondyle_y           0.0040      0.027      0.150      0.881      -0.048       0.056
# lateralEpicondyle_z          -0.0115      0.002     -4.799      0.000      -0.016      -0.007
# lateralPosteriorCondyle_x     0.5967      0.015     39.957      0.000       0.567       0.626
# lateralPosteriorCondyle_y    -0.0160      0.039     -0.416      0.677      -0.092       0.060
# lateralPosteriorCondyle_z    -0.0044      0.024     -0.186      0.852      -0.051       0.042
# medialEpicondyle_x            0.9071      0.017     54.039      0.000       0.874       0.940
# medialEpicondyle_y           -0.0177      0.027     -0.667      0.505      -0.070       0.034
# medialEpicondyle_z            0.0454      0.032      1.438      0.150      -0.016       0.107
# medialPosteriorCondyle_x     -0.6064      0.019    -32.180      0.000      -0.643      -0.569
# medialPosteriorCondyle_y      0.0343      0.039      0.889      0.374      -0.041       0.110
# medialPosteriorCondyle_z     -0.0294      0.042     -0.707      0.479      -0.111       0.052
# midfemurCenter_x              0.1622      0.012     13.970      0.000       0.139       0.185
# midfemurCenter_y             -0.0060      0.015     -0.412      0.680      -0.035       0.023
# midfemurCenter_z              0.0042      0.002      2.217      0.027       0.000       0.008
# ==============================================================================
# Omnibus:                       14.473   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.002
# Skew:                          -0.005   Prob(JB):                     2.75e-05
# Kurtosis:                       3.497   Cond. No.                     2.30e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
predictions2 = model2.predict(new_df_x)
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        femoralCenter_y   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          1.082e+05
# Date:                Thu, 27 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        20:03:29   Log-Likelihood:                         -4318.7
# No. Observations:                2039   AIC:                                      8679.
# Df Residuals:                    2018   BIC:                                      8797.
# Df Model:                          21
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# greaterTrochanter_x           0.0080      0.010      0.811      0.418      -0.011       0.027
# greaterTrochanter_y          -0.0362      0.007     -5.253      0.000      -0.050      -0.023
# greaterTrochanter_z          -0.0711      0.005    -14.533      0.000      -0.081      -0.062
# hipCenter_x                  -0.0142      0.010     -1.367      0.172      -0.035       0.006
# hipCenter_y                   0.0063      0.007      0.908      0.364      -0.007       0.020
# hipCenter_z                   0.0392      0.005      8.294      0.000       0.030       0.048
# lateralEpicondyle_x          -0.0026      0.004     -0.656      0.512      -0.011       0.005
# lateralEpicondyle_y           0.2752      0.019     14.248      0.000       0.237       0.313
# lateralEpicondyle_z          -0.0217      0.002    -12.537      0.000      -0.025      -0.018
# lateralPosteriorCondyle_x    -0.0026      0.011     -0.238      0.812      -0.024       0.019
# lateralPosteriorCondyle_y     0.3881      0.028     13.932      0.000       0.333       0.443
# lateralPosteriorCondyle_z     0.0307      0.017      1.781      0.075      -0.003       0.064
# medialEpicondyle_x           -0.0040      0.012     -0.333      0.739      -0.028       0.020
# medialEpicondyle_y            0.5292      0.019     27.596      0.000       0.492       0.567
# medialEpicondyle_z           -0.0581      0.023     -2.547      0.011      -0.103      -0.013
# medialPosteriorCondyle_x      0.0103      0.014      0.754      0.451      -0.016       0.037
# medialPosteriorCondyle_y     -0.1878      0.028     -6.728      0.000      -0.243      -0.133
# medialPosteriorCondyle_z      0.0834      0.030      2.773      0.006       0.024       0.142
# midfemurCenter_x              0.0024      0.008      0.285      0.776      -0.014       0.019
# midfemurCenter_y              0.0243      0.011      2.294      0.022       0.004       0.045
# midfemurCenter_z             -0.0023      0.001     -1.679      0.093      -0.005       0.000
# ==============================================================================
# Omnibus:                       54.074   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.484
# Skew:                          -0.226   Prob(JB):                     2.25e-20
# Kurtosis:                       3.928   Cond. No.                     2.30e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
predictions3 = model3.predict(new_df_x)
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        femoralCenter_z   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          4.916e+06
# Date:                Thu, 27 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        20:03:44   Log-Likelihood:                         -5541.3
# No. Observations:                2039   AIC:                                  1.112e+04
# Df Residuals:                    2018   BIC:                                  1.124e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# greaterTrochanter_x          -0.0185      0.018     -1.035      0.301      -0.054       0.017
# greaterTrochanter_y          -0.0153      0.013     -1.216      0.224      -0.040       0.009
# greaterTrochanter_z           0.2585      0.009     28.995      0.000       0.241       0.276
# hipCenter_x                   0.0201      0.019      1.064      0.288      -0.017       0.057
# hipCenter_y                  -0.0009      0.013     -0.074      0.941      -0.026       0.024
# hipCenter_z                  -0.2767      0.009    -32.154      0.000      -0.294      -0.260
# lateralEpicondyle_x           0.0020      0.007      0.277      0.782      -0.012       0.016
# lateralEpicondyle_y           0.0376      0.035      1.070      0.285      -0.031       0.107
# lateralEpicondyle_z          -0.0048      0.003     -1.520      0.129      -0.011       0.001
# lateralPosteriorCondyle_x     0.0277      0.020      1.410      0.159      -0.011       0.066
# lateralPosteriorCondyle_y    -0.0260      0.051     -0.512      0.609      -0.125       0.074
# lateralPosteriorCondyle_z     0.4680      0.031     14.916      0.000       0.406       0.530
# medialEpicondyle_x            0.0138      0.022      0.624      0.533      -0.030       0.057
# medialEpicondyle_y            0.2251      0.035      6.444      0.000       0.157       0.294
# medialEpicondyle_z            0.4947      0.042     11.917      0.000       0.413       0.576
# medialPosteriorCondyle_x     -0.0481      0.025     -1.940      0.053      -0.097       0.001
# medialPosteriorCondyle_y     -0.3022      0.051     -5.944      0.000      -0.402      -0.202
# medialPosteriorCondyle_z      0.0560      0.055      1.023      0.307      -0.051       0.163
# midfemurCenter_x              0.0007      0.015      0.044      0.965      -0.029       0.031
# midfemurCenter_y              0.0824      0.019      4.271      0.000       0.045       0.120
# midfemurCenter_z              0.0044      0.003      1.748      0.081      -0.001       0.009
# ==============================================================================
# Omnibus:                     4278.089   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         20586754.258
# Skew:                          17.321   Prob(JB):                         0.00
# Kurtosis:                     494.035   Cond. No.                     2.30e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
tempx = [predictions1,predictions2,predictions3]
